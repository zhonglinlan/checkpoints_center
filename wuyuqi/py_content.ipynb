# %% [markdown]
# # 一、基础知识
# ### 1.1安装python
# ### 1.2 交互式解释器
# ### 1.3 算法是什么
# ### 1.4 数字和表达式
# ### 1.5 变量
# ### 1.6 语句
# ### 1.7 获取用户输入
# ### 1.8 函数
# ### 1.9 模块
# ### 1.10 保存并执行程序
# ### 1.11 字符串
# ### 1.12 小结
#
# # 二、列表与元祖
# ### 2.1 序列概览
# ### 2.2 通用序列操作
# ### 2.3 列表 ：Python的苦力
# ### 2.4 元组：不可变序的列
# ### 2.5 小结
#
# # 三、使用字符串
# ### 3.1 基本字符串操作
# ### 3.1 基本字符串操作
# ### 3.1 基本字符串操作
# ### 3.2 字符串格式化：简版
# ### 3.3 字符串格式化：全
# ### 3.4 字符串方法
# ### 3.5 小结
#
# # 四、字典
# ### 4.1 字典的使用
# ### 4.2 创建和使用字典
# ### 4.3 小结
#
# # 五、条件、循环和其他语句
# ### 5.1 print和import的更多信息
# ### 5.2 赋值
# ### 5.3 语句块
# ### 5.4 条件和条件语句
# ### 5.5 循环
# ### 5.6 列表推导式---轻量级循环
# ### 5.7 三人行
# ### 5.8 小结
#
# # 六、抽象
# ### 6.1懒惰即美德
# ### 6.2抽象和结构
# ### 6.3创建函数
# ### 6.4参数
# ### 6.5作用域
# ### 6.6递归
# ### 6.7小结
#
# # 七、更加抽象
# ### 7.1 对象
# ### 7.2类和类型
# ### 7.3面向对象的思考
# ### 7.4小结
#
# # 八、异常
# ### 8.1什么是异常
# ### 8.2按自己的方式出错
# ### 8.3捕捉异常
# ### 8.4不止一个except语句
# ### 8.5用一个块来捕捉异常
# ### 8.6捕捉对象
# ### 8.7真正的全捕捉
# ### 8.8万事大吉
# ### 8.9最后
# ### 8.10异常与常数
# ### 8.11异常之禅
# ### 8.12小结
#
# # 第9章 魔法方法、属性和迭代器
# ### 9.1准备工作
# ### 9.2构造方法
# ### 9.3成员访问
# ### 9.4更多魔法
# ### 9.5属性
# ### 9.6迭代器
# ### 9.7生成器
# ### 9.8八皇后问题
# ### 9.9小结
#
# # 第10章 充电时刻
# ### 10.1模块
# ### 10.2探究模块
# ### 10.3标准库
# ### 10.4小结
#
# # 第11章 文件和素材
# ### 11.1打开文件
# ### 11.2基本的文件方法
# ### 11.3对文件内容进行迭代
# ### 11.4小结
#
# # 第12章 图形用户界面
# ### 12.1丰富的平台
# ### 12.2下载和安装wxpython
# ### 12.3创建实例GUI应用程序
# ### 12.4但是我宁愿用
# ### 12.5小结
#
# # 第13章 数据库支持
# ### 13.1python数据库编程接口
# ### 13.2SQlit和PySQlite
# ### 13.3小结
#
# # 第14章 网络编程
# ### 14.1少数几个网络设计模块
# ### 14.2socketserver
# ### 14.3多个连接
# ### 14.4twisted
# ### 14.5小结
#
#
# # 第15章 Python和万维网
# ### 15.1屏幕抓取
# ### 15.2使用CGI创建动态页面
# ### 15.3mod_python
# ### 15.4网络应用程序框架
# ### 15.5Web服务
# ### 15.6小结
#
# # 第16章 测试
# ### 16.1先测试，，后代码
# ### 16.2测试工具
# ### 16.3单元测试以外的内容
# ### 16.4小结
#
# # 第17章 扩展Python
# ### 17.1考虑哪个更重要
# ### 17.2非常简单的途径
# ### 17.3编写C语言扩展
# ### 17.4小结
#
#
# # 第18章 程序打包
# ### 18.1Distutils基础
# ### 18.2打包
# ### 18.3编译拓展
# ### 18.4使用py2exe创建可执行程序
# ### 18.5小结
#
#
# # 第19章 好玩的编程
# ### 19.1为什么要好玩
# ### 19.2程序设计的柔术
# ### 19.3原型设计
# ### 19.4配置
# ### 19.5日记记录
# ### 19.6如果还没饭
# ### 19.7如果还想学
# ### 19.8小结
#
#
# # 第20章 项目1：即时标记
# # 第21章 项目2：画幅好画
# # 第22章 项目3：万能的XML
# # 第23章 项目4：新闻聚合
# # 第24章 项目5：虚拟茶话会
# # 第25章 项目6：使用CGI进行远程编辑
# # 第26章 项目7：自定义电子公告板
# # 第27章 项目8：使用XML-RPC进行文件共享
# # 第28章 项目9：文件共享2——GUI版本
# # 第29章 项目10：DIY街机游戏
# # 附录A　简明版本
# # 附录B　Python参考手册
# # 附录C　在线资源
# # 附录D　Python 3.0
