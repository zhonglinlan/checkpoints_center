# %% [markdown]
# ### 1. popitem方法使用的功能作用：
#     scoundrel={'name':'Rabin','girlfriend':'Marion'}
#     key,value=scoundrel.popitem()
#
# ### 2.*rest的赋值作用
# x,y,z,*rest=1,2,3,4,5,6,78,9,5,6,3
#
# ### 3.if语句的简单使用
#     name=input('what is your name? ')
#     if name.endswith('Gumby'):
#     print('hello,mr.Gumby')
#
#     name=input('What is your name?')
#     if name.endswith('Gumby'):
#     if name.startswith('Mr.'):
#        print('hello,Mr.Gumby')
#       elif name.startswith('Mrs.'):
#        print('hello,Mrs.Gumby')
#       else:print('hello,Gumby')
#     else:
#       print('hello,stranger')
#
#     while与for循环
#     name=''
#     while not name:
#       name=input('enter your name:')
#       print('hello,%s'%name)
#
#     numbers=[0,3,2,5,8,6,4,5,7,9]
#     for number in numbers:
#       print (number)
#
#     from math import sqrt
#     for n in range(99,91,-1):
#      root = sqrt(n)
#      if root==int(root):
#       print (n)
#       break
#     else:
#       print("Did't find it")
#
# ### 4.列表推导式：轻量级
# [(x,y) for x in range(3) for y in range(5)]
#
# ### 5.函数
#     def hello(name):
#      return 'Hello,'+name+'!'
#
#     def fibs(num):
#      result=[0,1]
#      for i in range(num-2):
#         result.append(result[-2]+result[-1])
#      return result
#
#
# ### 小结：在Python学习语句块后，我发现语句的缩进非常重要。
#     这将直接影响到整体代码的结构问题对比Java语言，Python并
#     没有“；”“{}”这类符号来限定结构，这使得Python更加精
#     简，但也突出了细节的重要性
